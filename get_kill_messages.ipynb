# %%
input = """Found kill effect: [12:44:21] [Client thread/INFO]: [CHAT] Player was painted pretty by PilBerry.
Found kill effect: [12:44:21] [Client thread/INFO]: [CHAT] Player was deviled into the void by PilBerry.
Found kill effect: [12:44:21] [Client thread/INFO]: [CHAT] Player was flipped off the edge by PilBerry.
Found kill effect: [12:44:21] [Client thread/INFO]: [CHAT] Player was made sunny side up by PilBerry's Golem.
Found kill effect: [12:44:21] [Client thread/INFO]: [CHAT] Green Bed was scrambled by PilBerry!
Found kill effect: [12:44:34] [Client thread/INFO]: [CHAT] Player was struck down by PilBerry.
Found kill effect: [12:44:34] [Client thread/INFO]: [CHAT] Player was turned to dust by PilBerry.
Found kill effect: [12:44:34] [Client thread/INFO]: [CHAT] Player was melted by PilBerry.
Found kill effect: [12:44:34] [Client thread/INFO]: [CHAT] Player was turned to ash by PilBerry.
Found kill effect: [12:44:34] [Client thread/INFO]: [CHAT] Player was fried by PilBerry's Golem.
Found kill effect: [12:44:34] [Client thread/INFO]: [CHAT] Green Bed was incinerated by PilBerry!
Found kill effect: [12:44:52] [Client thread/INFO]: [CHAT] Player was struck down by PilBerry.
Found kill effect: [12:44:52] [Client thread/INFO]: [CHAT] Player was turned to dust by PilBerry.
Found kill effect: [12:44:52] [Client thread/INFO]: [CHAT] Player was melted by PilBerry.
Found kill effect: [12:44:52] [Client thread/INFO]: [CHAT] Player was turned to ash by PilBerry.
Found kill effect: [12:44:52] [Client thread/INFO]: [CHAT] Player was fried by PilBerry's Golem.
Found kill effect: [12:44:52] [Client thread/INFO]: [CHAT] Green Bed was incinerated by PilBerry!
Found kill effect: [12:44:58] [Client thread/INFO]: [CHAT] Player was given the cold shoulder by PilBerry.
Found kill effect: [12:44:58] [Client thread/INFO]: [CHAT] Player was hit off by a love bomb from PilBerry.
Found kill effect: [12:44:58] [Client thread/INFO]: [CHAT] Player was struck with Cupid's arrow by PilBerry.
Found kill effect: [12:44:58] [Client thread/INFO]: [CHAT] Green Bed was dismantled by PilBerry!
Found kill effect: [12:45:11] [Client thread/INFO]: [CHAT] Player was oinked by PilBerry.
Found kill effect: [12:45:11] [Client thread/INFO]: [CHAT] Player was distracted by a piglet from PilBerry.
Found kill effect: [12:45:11] [Client thread/INFO]: [CHAT] Player was oinked by PilBerry's Golem.
Found kill effect: [12:45:11] [Client thread/INFO]: [CHAT] Green Bed was gulped by PilBerry!
Found kill effect: [12:45:29] [Client thread/INFO]: [CHAT] Player was oinked by PilBerry.
Found kill effect: [12:45:29] [Client thread/INFO]: [CHAT] Player was distracted by a piglet from PilBerry.
Found kill effect: [12:45:29] [Client thread/INFO]: [CHAT] Player was oinked by PilBerry's Golem.
Found kill effect: [12:45:29] [Client thread/INFO]: [CHAT] Green Bed was gulped by PilBerry!
Found kill effect: [12:45:35] [Client thread/INFO]: [CHAT] Player was filled full of lead by PilBerry.
Found kill effect: [12:45:35] [Client thread/INFO]: [CHAT] Player was killed with dynamite by PilBerry.
Found kill effect: [12:45:35] [Client thread/INFO]: [CHAT] Green Bed was iced by PilBerry!
Found kill effect: [12:45:43] [Client thread/INFO]: [CHAT] Player was bitten by PilBerry.
Found kill effect: [12:45:43] [Client thread/INFO]: [CHAT] Player was distracted by a puppy placed by PilBerry.
Found kill effect: [12:45:43] [Client thread/INFO]: [CHAT] Green Bed was ripped apart by PilBerry!
Found kill effect: [12:45:50] [Client thread/INFO]: [CHAT] Player was glazed in BBQ sauce by PilBerry.
Found kill effect: [12:45:50] [Client thread/INFO]: [CHAT] Player was thrown chili powder at by PilBerry.
Found kill effect: [12:45:50] [Client thread/INFO]: [CHAT] Player was sliced up by PilBerry's Golem.
Found kill effect: [12:45:50] [Client thread/INFO]: [CHAT] Green Bed was deep fried by PilBerry!
[2276:1218/124600.329:ERROR:gpu_init.cc(523)] Passthrough is not supported, GL is disabled, ANGLE is 
Found kill effect: [12:46:10] [Client thread/INFO]: [CHAT] Player was buzzed to death by PilBerry.
Found kill effect: [12:46:10] [Client thread/INFO]: [CHAT] Player was bzzz'd into the void by PilBerry.
Found kill effect: [12:46:10] [Client thread/INFO]: [CHAT] Player was startled by PilBerry.
Found kill effect: [12:46:10] [Client thread/INFO]: [CHAT] Player was stung off the edge by PilBerry.
Found kill effect: [12:46:10] [Client thread/INFO]: [CHAT] Player was bee'd by PilBerry's Golem.
Found kill effect: [12:46:10] [Client thread/INFO]: [CHAT] Green Bed was stung by PilBerry!
Found kill effect: [12:46:15] [Client thread/INFO]: [CHAT] Player was whacked with a party balloon by PilBerry.
Found kill effect: [12:46:15] [Client thread/INFO]: [CHAT] Player was popped into the void by PilBerry.
Found kill effect: [12:46:15] [Client thread/INFO]: [CHAT] Player was shot with a roman candle by PilBerry.
Found kill effect: [12:46:15] [Client thread/INFO]: [CHAT] Player was launched like a firework by PilBerry.
Found kill effect: [12:46:15] [Client thread/INFO]: [CHAT] Player was lit up by PilBerry's Golem.
Found kill effect: [12:46:21] [Client thread/INFO]: [CHAT] Player was tragically backstabbed by PilBerry.
Found kill effect: [12:46:21] [Client thread/INFO]: [CHAT] Player was heartlessly let go by PilBerry.
Found kill effect: [12:46:21] [Client thread/INFO]: [CHAT] Player's heart was pierced by PilBerry.
Found kill effect: [12:46:21] [Client thread/INFO]: [CHAT] Player was delivered into nothingness by PilBerry.
Found kill effect: [12:46:21] [Client thread/INFO]: [CHAT] Player was dismembered by PilBerry's Golem.
Found kill effect: [12:46:21] [Client thread/INFO]: [CHAT] Green Bed was dreadfully corrupted by PilBerry!
Found kill effect: [12:46:28] [Client thread/INFO]: [CHAT] Player was smothered in holiday cheer by PilBerry.
Found kill effect: [12:46:28] [Client thread/INFO]: [CHAT] Player was banished into the ether by PilBerry's holiday spirit.
Found kill effect: [12:46:28] [Client thread/INFO]: [CHAT] Player was sniped by a missile of festivity by PilBerry.
Found kill effect: [12:46:28] [Client thread/INFO]: [CHAT] Player was pushed by PilBerry's holiday spirit.
Found kill effect: [12:46:28] [Client thread/INFO]: [CHAT] Player was sung holiday tunes to by PilBerry's Golem.
Found kill effect: [12:46:28] [Client thread/INFO]: [CHAT] Green Bed was melted by PilBerry's holiday spirit!
Found kill effect: [12:46:50] [Client thread/INFO]: [CHAT] Player was stomped by PilBerry.
Found kill effect: [12:46:50] [Client thread/INFO]: [CHAT] Player was thrown down a pit by PilBerry.
Found kill effect: [12:46:50] [Client thread/INFO]: [CHAT] Player was shot by PilBerry.
Found kill effect: [12:46:50] [Client thread/INFO]: [CHAT] Player was thrown to the ground by PilBerry.
Found kill effect: [12:46:50] [Client thread/INFO]: [CHAT] Player was outclassed by PilBerry's Golem.
Found kill effect: [12:46:50] [Client thread/INFO]: [CHAT] Green Bed was bed #1,515 destroyed by PilBerry!
Found kill effect: [12:46:56] [Client thread/INFO]: [CHAT] Player was spooked by PilBerry.
Found kill effect: [12:46:56] [Client thread/INFO]: [CHAT] Player was spooked off the map by PilBerry.
Found kill effect: [12:46:56] [Client thread/INFO]: [CHAT] Player was remotely spooked by PilBerry.
Found kill effect: [12:46:56] [Client thread/INFO]: [CHAT] Player was totally spooked by PilBerry.
Found kill effect: [12:46:56] [Client thread/INFO]: [CHAT] Player was spooked by PilBerry's Golem.
Found kill effect: [12:46:56] [Client thread/INFO]: [CHAT] Green Bed was spooked by PilBerry!
Found kill effect: [12:47:01] [Client thread/INFO]: [CHAT] Player was crushed by PilBerry.
Found kill effect: [12:47:01] [Client thread/INFO]: [CHAT] Player was dominated by PilBerry.
Found kill effect: [12:47:01] [Client thread/INFO]: [CHAT] Player was assassinated by PilBerry.
Found kill effect: [12:47:01] [Client thread/INFO]: [CHAT] Player was thrown off their high horse by PilBerry.
Found kill effect: [12:47:01] [Client thread/INFO]: [CHAT] Player was degraded by PilBerry's Golem.
Found kill effect: [12:47:01] [Client thread/INFO]: [CHAT] Green Bed was bed #1,515 destroyed by PilBerry!
Found kill effect: [12:47:08] [Client thread/INFO]: [CHAT] Player was yelled at by PilBerry.
Found kill effect: [12:47:08] [Client thread/INFO]: [CHAT] Player was thrown off the lawn by PilBerry.
Found kill effect: [12:47:08] [Client thread/INFO]: [CHAT] Player was accidentally spit on by PilBerry.
Found kill effect: [12:47:08] [Client thread/INFO]: [CHAT] Player was chased away by PilBerry's Golem.
Found kill effect: [12:47:08] [Client thread/INFO]: [CHAT] Green Bed was sold in a garage sale by PilBerry!
Found kill effect: [12:47:13] [Client thread/INFO]: [CHAT] Player was trampled by PilBerry.
Found kill effect: [12:47:13] [Client thread/INFO]: [CHAT] Player was back kicked into the void by PilBerry.
Found kill effect: [12:47:13] [Client thread/INFO]: [CHAT] Player was impaled from a distance by PilBerry.
Found kill effect: [12:47:13] [Client thread/INFO]: [CHAT] Player was headbutted off a cliff by PilBerry.
Found kill effect: [12:47:13] [Client thread/INFO]: [CHAT] Player was trampled by PilBerry's Golem.
Found kill effect: [12:47:13] [Client thread/INFO]: [CHAT] Green Bed was impaled by PilBerry!
Found kill effect: [12:47:36] [Client thread/INFO]: [CHAT] Player was hunted down by PilBerry.
Found kill effect: [12:47:36] [Client thread/INFO]: [CHAT] Player was thrown into a volcano by PilBerry.
Found kill effect: [12:47:36] [Client thread/INFO]: [CHAT] Player was mauled by PilBerry's Golem.
Found kill effect: [12:47:36] [Client thread/INFO]: [CHAT] Green Bed was sacrificed by PilBerry!
Found kill effect: [12:47:42] [Client thread/INFO]: [CHAT] Player was ripped to shreds by PilBerry.
Found kill effect: [12:47:42] [Client thread/INFO]: [CHAT] Player was charged by PilBerry.
Found kill effect: [12:47:42] [Client thread/INFO]: [CHAT] Player was pounced on by PilBerry.
Found kill effect: [12:47:42] [Client thread/INFO]: [CHAT] Player was ripped and thrown by PilBerry.
Found kill effect: [12:47:42] [Client thread/INFO]: [CHAT] Player was ripped to shreds by PilBerry's Golem.
Found kill effect: [12:47:42] [Client thread/INFO]: [CHAT] Green Bed was ripped to shreds by PilBerry.
Found kill effect: [12:47:49] [Client thread/INFO]: [CHAT] Player was wrapped into a gift by PilBerry.
Found kill effect: [12:47:49] [Client thread/INFO]: [CHAT] Player was put on the naughty list by PilBerry.
Found kill effect: [12:47:49] [Client thread/INFO]: [CHAT] Player was pushed down a slope by PilBerry.
Found kill effect: [12:47:49] [Client thread/INFO]: [CHAT] Player was turned to gingerbread by PilBerry's Golem.
Found kill effect: [12:47:49] [Client thread/INFO]: [CHAT] Green Bed was traded in for milk and cookies by PilBerry!
Found kill effect: [12:47:56] [Client thread/INFO]: [CHAT] Player was locked outside during a snow storm by PilBerry.
Found kill effect: [12:47:56] [Client thread/INFO]: [CHAT] Player was pushed into a snowbank by PilBerry.
Found kill effect: [12:47:56] [Client thread/INFO]: [CHAT] Player was shoved down an icy slope by PilBerry.
Found kill effect: [12:47:56] [Client thread/INFO]: [CHAT] Green Bed was made into a snowman by PilBerry!
Found kill effect: [12:48:01] [Client thread/INFO]: [CHAT] Player was chewed up by PilBerry.
Found kill effect: [12:48:01] [Client thread/INFO]: [CHAT] Player was scared into the void by PilBerry.
Found kill effect: [12:48:01] [Client thread/INFO]: [CHAT] Player was distracted by a rat dragging pizza from PilBerry.
Found kill effect: [12:48:01] [Client thread/INFO]: [CHAT] Green Bed was squeaked apart by PilBerry!
Found kill effect: [12:48:07] [Client thread/INFO]: [CHAT] Player was crushed into moon dust by PilBerry.
Found kill effect: [12:48:07] [Client thread/INFO]: [CHAT] Player was sent the wrong way by PilBerry.
Found kill effect: [12:48:07] [Client thread/INFO]: [CHAT] Player was hit by an asteroid from PilBerry.
Found kill effect: [12:48:07] [Client thread/INFO]: [CHAT] Player was blasted to the moon by PilBerry.
Found kill effect: [12:48:07] [Client thread/INFO]: [CHAT] Player was blown up by PilBerry's Golem.
Found kill effect: [12:48:07] [Client thread/INFO]: [CHAT] Green Bed was blasted to dust by PilBerry!
Found kill effect: [12:48:12] [Client thread/INFO]: [CHAT] Player was bested by PilBerry.
Found kill effect: [12:48:12] [Client thread/INFO]: [CHAT] Player was knocked into the void by PilBerry.
Found kill effect: [12:48:12] [Client thread/INFO]: [CHAT] Player was shot by PilBerry.
Found kill effect: [12:48:12] [Client thread/INFO]: [CHAT] Player was knocked off an edge by PilBerry.
Found kill effect: [12:48:12] [Client thread/INFO]: [CHAT] Player was bested by PilBerry's Golem.
Found kill effect: [12:48:12] [Client thread/INFO]: [CHAT] Green Bed was bed #1,515 destroyed by PilBerry!
Found kill effect: [12:48:17] [Client thread/INFO]: [CHAT] Player was wrapped up by PilBerry.
Found kill effect: [12:48:17] [Client thread/INFO]: [CHAT] Player was tied into a bow by PilBerry.
Found kill effect: [12:48:17] [Client thread/INFO]: [CHAT] Player was glued up by PilBerry.
Found kill effect: [12:48:17] [Client thread/INFO]: [CHAT] Player was taped together by PilBerry's Golem.
Found kill effect: [12:48:17] [Client thread/INFO]: [CHAT] Green Bed was stuffed with tissue paper by PilBerry!
Found kill effect: [12:50:03] [Client thread/INFO]: [CHAT] Player was coughed at by PilBerry.
Found kill effect: [12:50:03] [Client thread/INFO]: [CHAT] Green Bed was contaminated by PilBerry!
Found kill effect: [12:50:10] [Client thread/INFO]: [CHAT] Player was chewed up by PilBerry.
Found kill effect: [12:50:10] [Client thread/INFO]: [CHAT] Player was scared into the void by PilBerry.
Found kill effect: [12:50:10] [Client thread/INFO]: [CHAT] Player was distracted by a rat dragging pizza from PilBerry.
Found kill effect: [12:50:10] [Client thread/INFO]: [CHAT] Green Bed was squeaked apart by PilBerry!
Found kill effect: [12:50:22] [Client thread/INFO]: [CHAT] Player was crushed into moon dust by PilBerry.
Found kill effect: [12:50:22] [Client thread/INFO]: [CHAT] Player was sent the wrong way by PilBerry.
Found kill effect: [12:50:22] [Client thread/INFO]: [CHAT] Player was hit by an asteroid from PilBerry.
Found kill effect: [12:50:22] [Client thread/INFO]: [CHAT] Player was blasted to the moon by PilBerry.
Found kill effect: [12:50:22] [Client thread/INFO]: [CHAT] Player was blown up by PilBerry's Golem.
Found kill effect: [12:50:22] [Client thread/INFO]: [CHAT] Green Bed was blasted to dust by PilBerry!
Found kill effect: [12:50:28] [Client thread/INFO]: [CHAT] Player was bested by PilBerry.
Found kill effect: [12:50:28] [Client thread/INFO]: [CHAT] Player was knocked into the void by PilBerry.
Found kill effect: [12:50:28] [Client thread/INFO]: [CHAT] Player was shot by PilBerry.
Found kill effect: [12:50:28] [Client thread/INFO]: [CHAT] Player was knocked off an edge by PilBerry.
Found kill effect: [12:50:28] [Client thread/INFO]: [CHAT] Player was bested by PilBerry's Golem.
Found kill effect: [12:50:28] [Client thread/INFO]: [CHAT] Green Bed was bed #1,515 destroyed by PilBerry!
Found kill effect: [12:50:33] [Client thread/INFO]: [CHAT] Player was wrapped up by PilBerry.
Found kill effect: [12:50:33] [Client thread/INFO]: [CHAT] Player was tied into a bow by PilBerry.
Found kill effect: [12:50:33] [Client thread/INFO]: [CHAT] Player was glued up by PilBerry.
Found kill effect: [12:50:33] [Client thread/INFO]: [CHAT] Player was taped together by PilBerry's Golem.
Found kill effect: [12:50:33] [Client thread/INFO]: [CHAT] Green Bed was stuffed with tissue paper by PilBerry!"""
import re

lines = []

for line in input.split("\n"):
    line = line[59:]

    if 'Green Bed' in line:
        print(line)

    line = re.sub(r"Player|Green Bed|PilBerry", ".+", line)
    if line.endswith("."):
        line = line[:-1]
    
    if not line in lines:
        lines.append(line)

print(lines)
# Out:
# Green Bed was scrambled by PilBerry!
# Green Bed was incinerated by PilBerry!
# Green Bed was incinerated by PilBerry!
# Green Bed was dismantled by PilBerry!
# Green Bed was gulped by PilBerry!
# Green Bed was gulped by PilBerry!
# Green Bed was iced by PilBerry!
# Green Bed was ripped apart by PilBerry!
# Green Bed was deep fried by PilBerry!
# Green Bed was stung by PilBerry!
# Green Bed was dreadfully corrupted by PilBerry!
# Green Bed was melted by PilBerry's holiday spirit!
# Green Bed was bed #1,515 destroyed by PilBerry!
# Green Bed was spooked by PilBerry!
# Green Bed was bed #1,515 destroyed by PilBerry!
# Green Bed was sold in a garage sale by PilBerry!
# Green Bed was impaled by PilBerry!
# Green Bed was sacrificed by PilBerry!
# Green Bed was ripped to shreds by PilBerry.
# Green Bed was traded in for milk and cookies by PilBerry!
# Green Bed was made into a snowman by PilBerry!
# Green Bed was squeaked apart by PilBerry!
# Green Bed was blasted to dust by PilBerry!
# ...
